# %%
#1073741906 up
#1073741905 Down
from snake_game import SnakeGame, SimpleNeuralNetwork
import neat
import math

# %%
def eval(net):
    game = SnakeGame(net, use_neural_network=True)
    score = game.run()
    return math.sqrt(score)

# %%
input_size = 8
hidden_size = 16
output_size = 4

eval(SimpleNeuralNetwork(input_size, hidden_size, output_size))
# Out:
# [+] Game successfully initialized
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2 hidden_size = 16
#       3 output_size = 4
# ----> 5 eval(SimpleNeuralNetwork(input_size, hidden_size, output_size))
#
# Cell In[9], line 2, in eval(net)
#       1 def eval(net):
# ----> 2     game = SnakeGame(net, use_neural_network=True)
#       3     score = game.run()
#       4     return math.sqrt(score)
#
# File ~/Projects/Python Sem III Project/snake_game.py:45, in SnakeGame.__init__(self, frame_size_x, frame_size_y, difficulty, use_neural_network)
#      43 # Initialize game window
#      44 pygame.display.set_caption('Snake Eater')
# ---> 45 self.game_window = pygame.display.set_mode((frame_size_x, frame_size_y))
#      47 # Colors (R, G, B)
#      48 self.black = pygame.Color(0, 0, 0)
#
# TypeError: size must be two numbers

# %%
SnakeGame().run()
# Out:
# [+] Game successfully initialized
# 0

# %%
import numpy as np

# %%
test[[0, 0][0],[0, 0][1]] = 1

# %%
test = np.zeros((5, 5))

# %%
test = np.zeros(5)

# %%
test
# Out:
# array([0., 0., 0., 0., 0.])

# %%
test.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 test.append(1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
np.append(test, [1, 2])
# Out:
# array([0., 0., 0., 0., 0., 1., 2.])

# %%
5 % 5
# Out:
# 0

# %%
arr= [0, 1, 2]

# %%
arr.append([3, 4])

# %%
arr
# Out:
# [0, 1, 2, [3, 4]]

# %%
arr.append(5, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 arr.append(5, 6)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
value = 3.14159
rounded_value = round(value, 3)  # Rounds to 2 decimal places
print(rounded_value)
# Out:
# 3.142

# %%
from neat.math_util import softmax

# %%
softmax([197, 136, 257, 94])
# Out:
# [8.75651076269652e-27, 2.820770088460135e-53, 1.0, 1.6218080426054863e-71]

# %%
softmax([121, 222, 3333])
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 softmax([121, 222, 3333])
#
# File ~/anaconda3/envs/lyncan/lib/python3.13/site-packages/neat/math_util.py:42, in softmax(values)
#      38 def softmax(values):
#      39     """
#      40     Compute the softmax of the given value set, v_i = exp(v_i) / s,
#      41     where s = sum(exp(v_0), exp(v_1), ..)."""
# ---> 42     e_values = list(map(exp, values))
#      43     s = sum(e_values)
#      44     inv_s = 1.0 / s
#
# OverflowError: math range error

# %%
import math

# %%
math.acos(3/5)
# Out:
# 0.9272952180016123

# %%
math.cos(0.927)
# Out:
# 0.6002361482517589

# %%
3/5
# Out:
# 0.6
